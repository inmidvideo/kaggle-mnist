# %%
# %pylab inline
import numpy as np
from sklearn.cross_validation import train_test_split
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mnist_test = np.loadtxt('../data/test.csv', delimiter=',', dtype=int, skiprows=1)

# %%
with open('/Users/kai/Downloads/dansBest.txt') as f:
  dansData = f.readlines()

# %%
with open('/Users/kai/Downloads/myBest.csv') as f:
  myData = f.readlines()

# %%
len(dansData), len(myData)
# Out:
# (28001, 28001)

# %%
disagreements = []
for i in xrange(28001):
    if dansData[i].strip() != myData[i].strip():
        disagreements.append(i)
print disagreements
# Out:
# [13, 29, 82, 158, 164, 227, 244, 306, 313, 373, 410, 455, 461, 495, 627, 775, 840, 845, 1023, 1034, 1060, 1099, 1113, 1184, 1236, 1245, 1250, 1308, 1488, 1504, 1624, 1862, 1901, 1938, 1954, 2121, 2209, 2252, 2263, 2278, 2302, 2338, 2368, 2370, 2391, 2410, 2417, 2612, 2637, 2647, 2650, 2664, 2674, 2693, 2732, 2744, 2829, 2909, 2953, 2960, 2964, 2990, 3039, 3081, 3098, 3128, 3134, 3163, 3172, 3315, 3368, 3374, 3409, 3486, 3576, 3586, 3604, 3630, 3726, 3741, 3801, 3809, 3817, 3858, 3861, 3904, 3969, 4264, 4278, 4280, 4474, 4485, 4672, 4685, 4775, 4860, 4950, 4994, 5009, 5039, 5075, 5156, 5215, 5277, 5351, 5406, 5435, 5450, 5514, 5572, 5685, 5694, 5738, 5748, 5798, 5830, 5851, 5878, 5958, 6115, 6118, 6156, 6257, 6421, 6466, 6499, 6528, 6551, 6578, 6624, 6629, 6661, 6674, 6686, 6739, 6800, 6854, 6862, 6959, 7092, 7179, 7184, 7239, 7257, 7408, 7448, 7457, 7568, 7594, 7658, 7741, 7855, 7913, 8152, 8157, 8167, 8269, 8327, 8331, 8347, 8358, 8459, 8531, 8579, 8596, 8737, 8809, 8839, 9041, 9052
# ...

# %%
len(disagreements)
# Out:
# 531

# %%
dansData[13], myData[13]
# Out:
# ('13,9\r\n', '13,4\n')

# %%
# copied from notebook 02A_representation_of_data.ipynb
fig = plt.figure(figsize=(12, 12))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

# plot the digits: each image is 8x8 pixels
for i in xrange(17 * 16):
    ax = fig.add_subplot(17, 16, i + 1, xticks=[], yticks=[])
    ax.imshow(mnist_test[disagreements[i] - 1].reshape(28, 28), cmap=plt.cm.Greys, interpolation='nearest')
    
    # label the image with the target value
    ax.text(1, 8, dansData[disagreements[i]].strip().split(',')[1], color='green')
    ax.text(1, 25, myData[disagreements[i]].strip().split(',')[1], color='red')

# %%
# copied from notebook 02A_representation_of_data.ipynb
fig = plt.figure(figsize=(12, 12))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

# plot the digits: each image is 8x8 pixels
for i in xrange(17 * 16, 531):
    ax = fig.add_subplot(17, 16, i - 17*16 + 1, xticks=[], yticks=[])
    ax.imshow(mnist_test[disagreements[i] - 1].reshape(28, 28), cmap=plt.cm.Greys, interpolation='nearest')
    
    # label the image with the target value
    ax.text(1, 8, dansData[disagreements[i]].strip().split(',')[1], color='green')
    ax.text(1, 25, myData[disagreements[i]].strip().split(',')[1], color='red')
